# %% [markdown]
# ## Data Preparation
#
# ### In this notebook we will prepare our data for our search function to use.
# ### We stored our data in a csv file
#  diamonds_dataset.csv

# %%
# Import the needed modules...
import pandas as pd

# %% [markdown]
# ## Data Engineering
#  Get the data into dataframes

# %%
df1=pd.read_csv('diamonds_dataset.csv') # Creating data frame

# %%
df1
# Out:
#               id                                                url    shape  \
# 0       10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1       10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2        9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3       10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4        9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
# ...          ...                                                ...      ...
# 119302  10081678  https://www.brilliantearth.com//lab-diamonds-s...    Round
# 119303   9521564  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119304   9896730  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119305   9756570  https://www.brilliantearth.com//lab-diamonds-s...     Oval
# 119306   9293400  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
#
# ...

# %%
df2=df1.head(150) # Taking first 150 rows of the dataset for simplicity

# %%
df2
# Out:
#            id                                                url    shape  \
# 0    10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1    10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2     9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3    10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4     9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
# ..        ...                                                ...      ...
# 145  10084285  https://www.brilliantearth.com//loose-diamonds...    Round
# 146  10086206  https://www.brilliantearth.com//loose-diamonds...    Round
# 147  10085674  https://www.brilliantearth.com//loose-diamonds...    Round
# 148  10086650  https://www.brilliantearth.com//loose-diamonds...    Round
# 149  10086497  https://www.brilliantearth.com//loose-diamonds...    Round
#
#      price  carat        cut color clarity report     type  \
# ...

# %%
# We dropped unnecessary attributes from our dataset
df3=df2.drop(['url','date_fetched','clarity','report'],axis=1)

# %%
df3
# Out:
#            id    shape  price  carat        cut color     type
# 0    10086429    Round    400   0.30  Very Good     J  natural
# 1    10016334  Emerald    400   0.31      Ideal     I  natural
# 2     9947216  Emerald    400   0.30      Ideal     I  natural
# 3    10083437    Round    400   0.30      Ideal     I  natural
# 4     9946136  Emerald    400   0.30      Ideal     I  natural
# ..        ...      ...    ...    ...        ...   ...      ...
# 145  10084285    Round    450   0.30  Very Good     J  natural
# 146  10086206    Round    450   0.30  Very Good     J  natural
# 147  10085674    Round    450   0.30      Ideal     E  natural
# 148  10086650    Round    450   0.30  Very Good     I  natural
# 149  10086497    Round    450   0.30      Ideal     J  natural
#
# [150 rows x 7 columns]

# %%
# Setting the index as id
df3.set_index('id',inplace=True)

# %%
df3
# Out:
#             shape  price  carat        cut color     type
# id
# 10086429    Round    400   0.30  Very Good     J  natural
# 10016334  Emerald    400   0.31      Ideal     I  natural
# 9947216   Emerald    400   0.30      Ideal     I  natural
# 10083437    Round    400   0.30      Ideal     I  natural
# 9946136   Emerald    400   0.30      Ideal     I  natural
# ...           ...    ...    ...        ...   ...      ...
# 10084285    Round    450   0.30  Very Good     J  natural
# 10086206    Round    450   0.30  Very Good     J  natural
# 10085674    Round    450   0.30      Ideal     E  natural
# 10086650    Round    450   0.30  Very Good     I  natural
# 10086497    Round    450   0.30      Ideal     J  natural
#
# [150 rows x 6 columns]

# %%
# We are getting the information about our dataset i.e. column names,count,data type of each column etc.
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 10086429 to 10086497
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   shape   150 non-null    object
#  1   price   150 non-null    int64
#  2   carat   150 non-null    float64
#  3   cut     150 non-null    object
#  4   color   150 non-null    object
#  5   type    150 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.2+ KB

# %%
df3['cut']
# Out:
# id
# 10086429    Very Good
# 10016334        Ideal
# 9947216         Ideal
# 10083437        Ideal
# 9946136         Ideal
#               ...
# 10084285    Very Good
# 10086206    Very Good
# 10085674        Ideal
# 10086650    Very Good
# 10086497        Ideal
# Name: cut, Length: 150, dtype: object

# %%
df3
# Out:
#             shape  price  carat        cut color     type
# id
# 10086429    Round    400   0.30  Very Good     J  natural
# 10016334  Emerald    400   0.31      Ideal     I  natural
# 9947216   Emerald    400   0.30      Ideal     I  natural
# 10083437    Round    400   0.30      Ideal     I  natural
# 9946136   Emerald    400   0.30      Ideal     I  natural
# ...           ...    ...    ...        ...   ...      ...
# 10084285    Round    450   0.30  Very Good     J  natural
# 10086206    Round    450   0.30  Very Good     J  natural
# 10085674    Round    450   0.30      Ideal     E  natural
# 10086650    Round    450   0.30  Very Good     I  natural
# 10086497    Round    450   0.30      Ideal     J  natural
#
# [150 rows x 6 columns]

# %%
df3.loc[10084285] # Here we are acessing the entire row with the help of id attribute
# Out:
# shape        Round
# price          450
# carat          0.3
# cut      Very Good
# color            J
# type       natural
# Name: 10084285, dtype: object

# %%
df3.reset_index(inplace=True)

# %%
df3
# Out:
#            id    shape  price  carat        cut color     type
# 0    10086429    Round    400   0.30  Very Good     J  natural
# 1    10016334  Emerald    400   0.31      Ideal     I  natural
# 2     9947216  Emerald    400   0.30      Ideal     I  natural
# 3    10083437    Round    400   0.30      Ideal     I  natural
# 4     9946136  Emerald    400   0.30      Ideal     I  natural
# ..        ...      ...    ...    ...        ...   ...      ...
# 145  10084285    Round    450   0.30  Very Good     J  natural
# 146  10086206    Round    450   0.30  Very Good     J  natural
# 147  10085674    Round    450   0.30      Ideal     E  natural
# 148  10086650    Round    450   0.30  Very Good     I  natural
# 149  10086497    Round    450   0.30      Ideal     J  natural
#
# [150 rows x 7 columns]

# %%
df3.columns
# Out:
# Index(['id', 'shape', 'price', 'carat', 'cut', 'color', 'type'], dtype='object')

# %%
d=df3.columns.tolist()

# %%
d
# Out:
# ['id', 'shape', 'price', 'carat', 'cut', 'color', 'type']

# %% [markdown]
# ## Data Base Search

# %%
df3
# Out:
#            id    shape  price  carat        cut color     type
# 0    10086429    Round    400   0.30  Very Good     J  natural
# 1    10016334  Emerald    400   0.31      Ideal     I  natural
# 2     9947216  Emerald    400   0.30      Ideal     I  natural
# 3    10083437    Round    400   0.30      Ideal     I  natural
# 4     9946136  Emerald    400   0.30      Ideal     I  natural
# ..        ...      ...    ...    ...        ...   ...      ...
# 145  10084285    Round    450   0.30  Very Good     J  natural
# 146  10086206    Round    450   0.30  Very Good     J  natural
# 147  10085674    Round    450   0.30      Ideal     E  natural
# 148  10086650    Round    450   0.30  Very Good     I  natural
# 149  10086497    Round    450   0.30      Ideal     J  natural
#
# [150 rows x 7 columns]

# %%
# In this section we are creating the list of id of diamond having the features of diamond.
id_list=df3.id.tolist()
id_list
# Out:
# [10086429,
#  10016334,
#  9947216,
#  10083437,
#  9946136,
#  10070154,
#  10086507,
#  10083288,
#  10090935,
#  9943628,
#  10055476,
#  10086105,
#  10082791,
#  10084879,
#  10087558,
#  9998192,
#  10083170,
#  10084818,
#  10048801,
#  10018558,
#  10087239,
#  9926525,
#  10085677,
#  10078896,
#  9926562,
#  10084000,
#  10083255,
#  9968964,
#  10086394,
#  9943656,
#  10085531,
#  10085242,
#  10017664,
#  10018977,
#  9997898,
#  10083855,
#  10085658,
#  9946103,
#  10088017,
#  9944355,
#  9944542,
#  9946958,
#  9947491,
#  10084951,
#  9967595,
#  9946002,
#  10010529,
#  10083303,
#  10086230,
#  10082181,
#  10082715,
#  10086414,
#  10021869,
#  10082854,
#  10017659,
#  10021227,
#  10085576,
#  10086541,
#  10086607,
#  10083440,
#  10081905,
#  10083628,
#  10084616,
#  10085191,
#  10086398,
#  10069564,
#  10085647,
#  9943802,
#  10086613,
#  10017866,
#  10035452,
#  9981968,
#  9946479,
#  10061364,
#  10082500,
#  10053036,
#  9989482,
#  10086205,
# ...

# %%
#Here we are comparing the id of diamond with the dataset.

def search_id(id):   #In this section we are giving id as argument.
    if id in id_list:
        print("The entered id in the dataset")
        
    else:
        print("The entered id is incorrect ")
        
    if type(id) != int:
        print("You has entered the id in different format")
        print("so, enter the id in integer")

# %%
search_id(10048801)
# Out:
# The entered id in the dataset

# %%
search_id(3456789)
# Out:
# The entered id is incorrect

# %%
search_id("6776")
# Out:
# The entered id is incorrect
# You has entered the id in different format
# so, enter the id in integer
